# %% [markdown]
# ### Introduction:
# The following code performs the three cases UCCSD-VQE studied in the paper [Parameter Redundancy in the Unitary Coupled-Cluster Ansatze for Hybrid Variational Quantum Computing](https://arxiv.org/pdf/2301.09825.pdf). The three cases are, 1) Conventional UCCSD-VQE, 2) Spin-adapted UCC-VQE (SA-UCCSD-VQE) and 3) Spin-Adapted Small Amplitude Filtered UCCSD-VQE (SA-SAF-UCCSD-VQE). The description of these methods is elaborated in the above attached paper. Here, we provide the corresponding pyhon code that generates the numerical results included in the paper.
#
# ### Prerequisites:
# To run the code seemlessly, the following modules of python are required:
# 1)qiskit\
# 2)qiskit_nature\
# 3)scipy\
# 4)numpy\
# 5)pickle\
# 6)copy\
# 7)matplotlib\
# 8)pandas\
# \
# We begin by importing all the neccessary methods and functions

# %%
from scipy.optimize import minimize
from qiskit_nature.drivers import UnitsType, Molecule
from qiskit_nature.drivers.second_quantization import ElectronicStructureDriverType, ElectronicStructureMoleculeDriver
from qiskit_nature.problems.second_quantization import ElectronicStructureProblem
from qiskit_nature.converters.second_quantization import QubitConverter
from qiskit_nature.mappers.second_quantization import JordanWignerMapper, ParityMapper, BravyiKitaevMapper
from qiskit.opflow.converters import TwoQubitReduction
from qiskit_nature.algorithms.ground_state_solvers.minimum_eigensolver_factories import NumPyMinimumEigensolverFactory
from qiskit_nature.algorithms.ground_state_solvers import GroundStateEigensolver
from qiskit_nature.circuit.library.initial_states.hartree_fock import *
from qiskit.opflow import *
from qiskit import Aer
from qiskit.algorithms.optimizers import COBYLA, L_BFGS_B, SPSA, SLSQP
from qiskit.algorithms import VQE
from qiskit_nature.circuit.library.ansatzes import UCC
from qiskit.utils import *
from qiskit_nature.circuit.library.ansatzes.utils import generate_fermionic_excitations
import time
import pickle
import copy 
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### Convention for cluster amplitudes:
# In the fillowing, the convension is as follows: \
# Letters i,j,.. correspond to occupied $\alpha$ spin orbitals.\
# Letters I,J,.. correspond to occupied $\beta$ spin orbitals.\
# Letters a,b,.. correspond to unoccupied $\alpha$ spin orbitals.\
# Letters A,B,.. correspond to unoccupied $\beta$ spin orbitals.\
# So an amplitude of the form t_i_a corresponds to the excitation that takes an electron from occupied $\alpha$ spin orbital 'i', to an unoccupied $\alpha$ spin orbital 'a'. Similar notation convention holds for double excitations.
#
# Let us define a funciton that performs spin adaptation with input as a list of excitations to be included in the cluster operator. The function regroups the set of input excitations in a specific order and stores it in the list `spin_nonadapted_exct`. It then performs spin adaptation on this list, leading to a new list, `spin_adapted_exct`, which only contains unique excitations according to the spin adaptation procedure.

# %%
def perform_spin_adaptation(relevant_excitations):
  global t_i_a, t_I_A, t_ij_ab, t_IJ_AB, t_iJ_aB, t_iJ_Ab, t_iJ_aA, t_Ij_Ab, t_Ij_aB, t_Ij_aA, t_iI_aB, t_iI_Ab, t_iI_aA
  global spin_nonadapted_exct
  global nonadapted_t_i_a_idx, nonadapted_t_I_A_idx, nonadapted_t_ij_ab_idx, nonadapted_t_IJ_AB_idx, nonadapted_t_iJ_aB_idx, nonadapted_t_Ij_Ab_idx, nonadapted_t_iJ_Ab_idx, nonadapted_t_Ij_aB_idx, nonadapted_t_iJ_aA_idx, nonadapted_t_Ij_aA_idx, nonadapted_t_iI_aB_idx, nonadapted_t_iI_Ab_idx, nonadapted_t_iI_aA_idx
  global spin_adapted_exct
  global adapted_t_i_a_idx, adapted_t_ij_ab_idx, adapted_t_iJ_aB_idx, adapted_t_iJ_aA_idx, adapted_t_iI_aB_idx, adapted_t_iI_aA_idx
  global nonadapted_exct_index_extractor
  global adapted_exct_index_extractor
  global adapted_to_nonadapted_idx


  singles = [i for i in relevant_excitations if len(i[0])==1] #extracting the single excitations
  doubles = [i for i in relevant_excitations if len(i[0])==2] #extracting the double excitations


  t_i_a = []
  for i in singles:
      if i[0][0]<nso:
          t_i_a.append(i)

  t_I_A = []
  for i in t_i_a:
      t_I_A.append(((i[0][0]+nso,), (i[1][0]+nso,)))




  t_ij_ab = []
  for i in doubles:
      if i[0][0]<nso and i[0][1]<nso:
          t_ij_ab.append(i)
  t_IJ_AB = []
  for i in t_ij_ab:
      t_IJ_AB.append(((i[0][0]+nso, i[0][1]+nso), (i[1][0]+nso, i[1][1]+nso)))
      
      

  t_iJ_aB = []
  for i in t_ij_ab:
      x = ((i[0][0], i[0][1]+nso), (i[1][0], i[1][1]+nso))
      if x in doubles:
          t_iJ_aB.append(x)
  for i in doubles:
      if i[0][0]<i[0][1]-nso and i[1][0]<i[1][1]-nso and i not in t_iJ_aB:
          t_iJ_aB.append(i)
        
      
  t_iJ_Ab = []
  for i in t_ij_ab:
      x = ((i[0][0], i[0][1]+nso), (i[1][1], i[1][0]+nso))
      if x in doubles:
          t_iJ_Ab.append(x)
  for i in t_iJ_aB:
      x = (i[0], (i[1][1]-nso, i[1][0]+nso))
      if x in doubles and x not in t_iJ_Ab:
          t_iJ_Ab.append(x)

      
      
  t_iJ_aA = []
  for i in doubles:
      if i[0][0]<i[0][1]-nso and i[1][0]==i[1][1]-nso:
          t_iJ_aA.append(i)




  t_Ij_Ab = []
  for i in t_iJ_aB:
      t_Ij_Ab.append( ((i[0][1]-nso, i[0][0]+nso), (i[1][1]-nso, i[1][0]+nso)) )
          
  t_Ij_aB = []
  for i in t_iJ_Ab:
      t_Ij_aB.append(((i[0][1]-nso, i[0][0]+nso), (i[1][1]-nso, i[1][0]+nso)))

  t_Ij_aA = []
  for i in t_iJ_aA:
      t_Ij_aA.append(((i[0][1]-nso, i[0][0]+nso), i[1]))




  t_iI_aB = []
  for i in doubles:
      if i[0][0]==i[0][1]-nso and i[1][0]<i[1][1]-nso:
          t_iI_aB.append(i)

  t_iI_Ab = []
  for i in t_iI_aB:
      t_iI_Ab.append((i[0], (i[1][1]-nso, i[1][0]+nso)))
          
  t_iI_aA = []
  for i in doubles:
      if i[0][0]==i[0][1]-nso and i[1][0]==i[1][1]-nso:
          t_iI_aA.append(i)


  #List of excitations without applying spin adaptation, arranged in a specific order.
  spin_nonadapted_exct = t_i_a + t_I_A + t_ij_ab + t_IJ_AB + t_iJ_aB + t_Ij_Ab + t_iJ_Ab + t_Ij_aB + t_iJ_aA + t_Ij_aA + t_iI_aB + t_iI_Ab + t_iI_aA

  #Given an excitation, the following function returns all the indices of the excitations in the above list that are equivalent to it according to spin adaptation.
  def nonadapted_exct_index_extractor (t_pq_rs):
      return [i for i in range(len(spin_nonadapted_exct)) if spin_nonadapted_exct[i] in t_pq_rs]
  nonadapted_t_i_a_idx = nonadapted_exct_index_extractor(t_i_a)
  nonadapted_t_I_A_idx = nonadapted_exct_index_extractor(t_I_A)
  nonadapted_t_ij_ab_idx = nonadapted_exct_index_extractor(t_ij_ab)
  nonadapted_t_IJ_AB_idx = nonadapted_exct_index_extractor(t_IJ_AB)
  nonadapted_t_iJ_aB_idx = nonadapted_exct_index_extractor(t_iJ_aB)
  nonadapted_t_Ij_Ab_idx = nonadapted_exct_index_extractor(t_Ij_Ab)
  nonadapted_t_iJ_Ab_idx = nonadapted_exct_index_extractor(t_iJ_Ab)
  nonadapted_t_Ij_aB_idx = nonadapted_exct_index_extractor(t_Ij_aB)
  nonadapted_t_iJ_aA_idx = nonadapted_exct_index_extractor(t_iJ_aA)
  nonadapted_t_Ij_aA_idx = nonadapted_exct_index_extractor(t_Ij_aA)
  nonadapted_t_iI_aB_idx = nonadapted_exct_index_extractor(t_iI_aB)
  nonadapted_t_iI_Ab_idx = nonadapted_exct_index_extractor(t_iI_Ab)
  nonadapted_t_iI_aA_idx = nonadapted_exct_index_extractor(t_iI_aA)


  #List of excitations after applying spin adaptation, arranged in a specific order.
  spin_adapted_exct = t_i_a + t_ij_ab + t_iJ_aB + t_iJ_aA + t_iI_aB + t_iI_aA

  #Given an excitation, the following function returns all the indices of the excitations in the above list that are equivalent to it according to spin adaptation.
  def adapted_exct_index_extractor (t_pq_rs):
      return [i for i in range(len(spin_adapted_exct)) if spin_adapted_exct[i] in t_pq_rs]
  adapted_t_i_a_idx = adapted_exct_index_extractor(t_i_a)
  adapted_t_ij_ab_idx = adapted_exct_index_extractor(t_ij_ab)
  adapted_t_iJ_aB_idx = adapted_exct_index_extractor(t_iJ_aB)
  adapted_t_iJ_aA_idx = adapted_exct_index_extractor(t_iJ_aA)
  adapted_t_iI_aB_idx = adapted_exct_index_extractor(t_iI_aB)
  adapted_t_iI_aA_idx = adapted_exct_index_extractor(t_iI_aA)

  #Given an excitation from the list "spin_adapted_exct", the following function returns all the excitations that are equivalent to it and present in the the list "spin_nonadapted_exct".
  def adapted_to_nonadapted_idx (T_pq_rs):
      try:
          idx = adapted_t_i_a_idx.index(T_pq_rs)
          return [nonadapted_t_i_a_idx[idx], nonadapted_t_I_A_idx[idx]]
      except ValueError:
          pass
      
      try:
          idx = adapted_t_ij_ab_idx.index(T_pq_rs)
          return [nonadapted_t_ij_ab_idx[idx], nonadapted_t_IJ_AB_idx[idx]]
      except ValueError:
          pass
      
      try:
          idx = adapted_t_iJ_aB_idx.index(T_pq_rs)
          return [nonadapted_t_iJ_aB_idx[idx], nonadapted_t_Ij_Ab_idx[idx]]
      except ValueError:
          pass
      
      try:
          idx = adapted_t_iJ_aA_idx.index(T_pq_rs)
          return [nonadapted_t_iJ_aA_idx[idx], nonadapted_t_Ij_aA_idx[idx]]
      except ValueError:
          pass

      try:
          idx = adapted_t_iI_aB_idx.index(T_pq_rs)
          return [nonadapted_t_iI_aB_idx[idx], nonadapted_t_iI_Ab_idx[idx]]
      except ValueError:
          pass
      
      try:
          idx = adapted_t_iI_aA_idx.index(T_pq_rs)
          return [nonadapted_t_iI_aA_idx[idx]]
      except ValueError:
          pass

# %% [markdown]
# We will now define a function that can evaluate the expectation of a Hamiltonian, given the set of spin-adapted parameters. In the function, the step of evaluating the expectation is done using the function `energy_eval_func`. Note, although at this point we have not defined this function, it will be defined later before calling `adapted_energy_eval_func`.

# %%
def adapted_energy_eval_func(adapted_params):
    global nonadapted_params
    nonadapted_params = np.zeros_like(t)
    for i,j in zip([adapted_t_i_a_idx, adapted_t_ij_ab_idx, adapted_t_iJ_aB_idx, adapted_t_iJ_aA_idx, adapted_t_iI_aB_idx, adapted_t_iI_aA_idx], [nonadapted_t_i_a_idx, nonadapted_t_ij_ab_idx, nonadapted_t_iJ_aB_idx, nonadapted_t_iJ_aA_idx, nonadapted_t_iI_aB_idx, nonadapted_t_iI_aA_idx]):
        nonadapted_params[j] = adapted_params[i]
    nonadapted_params[nonadapted_t_I_A_idx] = adapted_params[adapted_t_i_a_idx]
    nonadapted_params[nonadapted_t_IJ_AB_idx] = adapted_params[adapted_t_ij_ab_idx]
    nonadapted_params[nonadapted_t_Ij_Ab_idx] = adapted_params[adapted_t_iJ_aB_idx]
    if len(nonadapted_t_iJ_Ab_idx) == len(nonadapted_t_ij_ab_idx) and len(nonadapted_t_iJ_Ab_idx) == len(nonadapted_t_iJ_aB_idx):
        nonadapted_params[nonadapted_t_iJ_Ab_idx] = adapted_params[adapted_t_ij_ab_idx] + adapted_params[adapted_t_iJ_aB_idx]    
    else:
        for i in nonadapted_t_iJ_Ab_idx:
            p = t_iJ_Ab[i-min(nonadapted_t_iJ_Ab_idx)]
            t1 = ((p[0][0], p[0][1]-nso), (p[1][1]-nso, p[1][0]))
            try:
                idx1 = t_ij_ab.index(t1)
                nonadapted_params[i] += adapted_params[adapted_t_ij_ab_idx[idx1]]
            except ValueError:
                pass
            t2 = ((p[0][0], p[0][1]), (p[1][1]-nso, p[1][0]+nso))
            try:
                idx2 = t_iJ_aB.index(t2)
                nonadapted_params[i] += adapted_params[adapted_t_iJ_aB_idx[idx2]]
            except ValueError:
                pass
    nonadapted_params[nonadapted_t_Ij_aB_idx] = nonadapted_params[nonadapted_t_iJ_Ab_idx]
    nonadapted_params[nonadapted_t_Ij_aA_idx] = adapted_params[adapted_t_iJ_aA_idx]
    nonadapted_params[nonadapted_t_iI_Ab_idx] = adapted_params[adapted_t_iI_aB_idx]

    a = energy_eval_func(nonadapted_params)
    return a

# %% [markdown]
# We can now write functions that perform the VQE with either spin-adapted ansatz or with the original ansatz (without spin-adaptation) for `maxiter` number of iterations.

# %%
#Given the number of maximum iterations allowed, the following function performs the Spin Adapted VQE.
def spin_adapted_VQE(maxiter):
  global adapted_ordered_params
  global x_0

  t0 = 0
  nonadapted_params = np.zeros_like(t)       #Will be used later
  print ('Energy at the initial parameter values: ', adapted_energy_eval_func(x_0) + result_exact.nuclear_repulsion_energy)
  
  iter_count = 0                          #Counts the number of iterations taken for convergence.
  #Callback function for minimization


  def print_fun(adapted_params):
      global adapted_ordered_params
      adapted_ordered_params = np.concatenate((adapted_ordered_params, adapted_params.reshape(1,len(spin_adapted_exct))))
      global iter_count
      iter_count += 1
      print ('Iteration %i:' %(iter_count), '   Energy = %f'%(adapted_energy_eval_func(adapted_params) + result_exact.nuclear_repulsion_energy))

  t0 = time.perf_counter()
  minimization_result = minimize(fun=adapted_energy_eval_func, x0=x_0, method='L-BFGS-B', tol = 1e-8, options={'maxiter': maxiter}, callback = print_fun)
  t1 = time.perf_counter()

  adapted_ordered_params = np.delete(adapted_ordered_params, (0), axis=0)

  UCC_E = adapted_energy_eval_func(adapted_ordered_params[-1,:]) + result_exact.nuclear_repulsion_energy
  print ('Final energy after minimization: ', UCC_E)  
  print ('Time ellapsed: ', t1-t0, '\n')

  return adapted_ordered_params










#Given the number of maximum iterations allowed, the following function performs the Non Spin Adapted VQE.
def nonspin_adapted_VQE(maxiter):
  global x_0
  print ('Energy at the initial parameter values: ', energy_eval_func(x_0) + result_exact.nuclear_repulsion_energy)
  UCC_E = 0

  global ordered_params

  iter_count = 0                          #Counts the number of iterations taken for convergence.
  #Callback function for minimization
  def print_fun(x):
      global ordered_params
      ordered_params = np.concatenate((ordered_params, x.reshape(1,len(t))))
      global iter_count
      iter_count += 1
      print ('Iteration %i:' %(iter_count), '   Energy = %f'%(energy_eval_func(x) + result_exact.nuclear_repulsion_energy))

  t0 = time.perf_counter()
  minimization_result = minimize(fun=energy_eval_func, x0=x_0, method='L-BFGS-B', tol = 1e-8, options={'maxiter': maxiter}, callback = print_fun)
  t1 = time.perf_counter()

  ordered_params = np.delete(ordered_params, (0), axis=0)

  UCC_E = energy_eval_func(ordered_params[-1,:]) + result_exact.nuclear_repulsion_energy
  print ('Final energy after minimization: ', UCC_E)  
  print ('Time ellapsed: ', t1-t0, '\n')
  return ordered_params

# %% [markdown]
# ### Creating a checkpoint:
# Before we begin the main part of the code, we have added a small step that acts as a check point i.e. if the code was interrupted in the previous run, the check point ensures that the code resumes from the previous point of interruption.
#
#
# ### Conventions used in storing the data:
# We are also saving the data generated by the code in the following format. Create the nest of directories: `Final data/Pre ML Data/H4_Linear` in the directory in which the current code is running. If the code is used to generate data for a different molecule, create the subdirectory after the name of the momlecule in the place of H4_Linear. For example, for LiH molecule, create the nest of directories `Final data/Pre ML Data/LiH`.
#
# The important sets of data being stored includes energy of the molecule, the time taken to attain convergence and, the parameters of the cluster amplitudes at each step of minimization, for each of the three cases discused above.
#
# `H4_Linear_SA_0_SAF_0_Energy` corresponds to energy of UCCSD-VQE.\
# `H4_Linear_SA_1_SAF_0_Energy` corresponds to energy of SA-UCCSD-VQE.\
# `H4_Linear_SA_1_SAF_1_Energy` corresponds to energy of SA-SAF-UCCSD-VQE.
#
# Similar name convention is followed for parameters and time.

# %%
#To start from an intermediate step
try:
    with open('Final data/Pre ML Data/H20/Cases_Completed.pkl', 'rb') as infile:
        Cases_Completed = pickle.load(infile)
except FileNotFoundError:
    Cases_Completed = []

try:
    with open('Final data/Pre ML Data/H20/Bond_Lengths.pkl', 'rb') as infile:
        Bond_Lengths = pickle.load(infile)
    with open('Final data/Pre ML Data/H20/H20_True_Energies.pkl', 'rb') as infile:
        molecule_True_Energies = pickle.load(infile)
    molecule_True_Energies = molecule_True_Energies[:len(Bond_Lengths)]    
except FileNotFoundError:
    Bond_Lengths = []
    molecule_True_Energies = []    
        
        
        

    


try:
    with open('Final data/Pre ML Data/H20/H20_SA_0_SAF_0_Params.pkl', 'rb') as infile:
        molecule_SA_0_SAF_0_Params = pickle.load(infile)
    with open('Final data/Pre ML Data/H20/H20_SA_0_SAF_0_Energies.pkl', 'rb') as infile:
        molecule_SA_0_SAF_0_Energies = pickle.load(infile)
    with open('Final data/Pre ML Data/H20/H20_SA_0_SAF_0_Time.pkl', 'rb') as infile:
        molecule_SA_0_SAF_0_Time = pickle.load(infile) 
    min_len = min([len(molecule_SA_0_SAF_0_Params), len(molecule_SA_0_SAF_0_Energies), len(molecule_SA_0_SAF_0_Time)])
    molecule_SA_0_SAF_0_Params = molecule_SA_0_SAF_0_Params[:min_len]
    molecule_SA_0_SAF_0_Energies = molecule_SA_0_SAF_0_Energies[:min_len]
    molecule_SA_0_SAF_0_Time = molecule_SA_0_SAF_0_Time[:min_len]         
except FileNotFoundError:
    molecule_SA_0_SAF_0_Params = []
    molecule_SA_0_SAF_0_Energies = []
    molecule_SA_0_SAF_0_Time = []


    

try:
    with open('Final data/Pre ML Data/H20/H20_SA_1_SAF_0_Params.pkl', 'rb') as infile:
        molecule_SA_1_SAF_0_Params = pickle.load(infile)
    with open('Final data/Pre ML Data/H20/H20_SA_1_SAF_0_Energies.pkl', 'rb') as infile:
        molecule_SA_1_SAF_0_Energies = pickle.load(infile)
    with open('Final data/Pre ML Data/H20/H20_SA_1_SAF_0_Time.pkl', 'rb') as infile:
        molecule_SA_1_SAF_0_Time = pickle.load(infile)
    min_len = min([len(molecule_SA_1_SAF_0_Params), len(molecule_SA_1_SAF_0_Energies), len(molecule_SA_1_SAF_0_Time)])
    molecule_SA_1_SAF_0_Params = molecule_SA_1_SAF_0_Params[:min_len]
    molecule_SA_1_SAF_0_Energies = molecule_SA_1_SAF_0_Energies[:min_len]
    molecule_SA_1_SAF_0_Time = molecule_SA_1_SAF_0_Time[:min_len]  
except FileNotFoundError:
    molecule_SA_1_SAF_0_Params = []
    molecule_SA_1_SAF_0_Energies = []
    molecule_SA_1_SAF_0_Time = []
    

    
try:
    with open('Final data/Pre ML Data/H20/H20_SA_1_SAF_1_Params.pkl', 'rb') as infile:
        molecule_SA_1_SAF_1_Params = pickle.load(infile)
    with open('Final data/Pre ML Data/H20/H20_SA_1_SAF_1_Energies.pkl', 'rb') as infile:
        molecule_SA_1_SAF_1_Energies = pickle.load(infile)
    with open('Final data/Pre ML Data/H20/H20_SA_1_SAF_1_Time.pkl', 'rb') as infile:
        molecule_SA_1_SAF_1_Time = pickle.load(infile)
    with open('Final data/Pre ML Data/H20/H20_spin_adapted_Removable_Idx.pkl', 'rb') as infile:
        molecule_spin_adapted_Removable_Idx = pickle.load(infile)
    with open('Final data/Pre ML Data/H20/H20_nonspin_adapted_Removable_Idx.pkl', 'rb') as infile:
        molecule_nonspin_adapted_Removable_Idx = pickle.load(infile)       
    min_len = min([len(molecule_SA_1_SAF_1_Params), len(molecule_SA_1_SAF_1_Energies), len(molecule_SA_1_SAF_1_Time), len(molecule_spin_adapted_Removable_Idx), len(molecule_nonspin_adapted_Removable_Idx)])
    molecule_SA_1_SAF_1_Params = molecule_SA_1_SAF_1_Params[:min_len]
    molecule_SA_1_SAF_1_Energies = molecule_SA_1_SAF_1_Energies[:min_len]
    molecule_SA_1_SAF_1_Time = molecule_SA_1_SAF_1_Time[:min_len]
    molecule_spin_adapted_Removable_Idx = molecule_spin_adapted_Removable_Idx[:min_len]
    molecule_nonspin_adapted_Removable_Idx = molecule_nonspin_adapted_Removable_Idx[:min_len]
except FileNotFoundError:
    molecule_SA_1_SAF_1_Params = []
    molecule_SA_1_SAF_1_Energies = []
    molecule_SA_1_SAF_1_Time = []
    molecule_spin_adapted_Removable_Idx = []
    molecule_nonspin_adapted_Removable_Idx = []

# %% [markdown]
# ### Following performs the main part of the code: 1) UCCSD-VQE, 2) SA-UCCSD-VQE and, 3) SA-SAF-UCCSD-VQE

# %%
maxiter = 35      #maxiter is the maximum number of iterations allowed during minimization

#Selecting the backend
backend = Aer.get_backend('aer_simulator_statevector')
optimizer = L_BFGS_B(maxiter)                          

#The code performs three different cases mentioned above: Case 1) SA-SAF-UCCSD-VQE, 2) SA-UCCSD-VQE and 3) UCCSD-VQE
All_cases = [('True', 'True'), ('True', 'False'), ('False', 'False')]
for case_idx in range (len(All_cases)):
    if len(Cases_Completed) == 0:
        case = All_cases[case_idx]
    else:
        case_idx = Cases_Completed[-1]+1
        case = All_cases[case_idx]
        
    print ('_______________________________Starting case: %i_______________________________'%(case_idx+1))
    include_spin_adaptation = case[0]
    include_spin_filtration = case[1]

    #To select a molecule from below, bring it outside of the comment block. "left" and "right" set the range of bond length to be considered.
    '''
    # H4 Linear
    left = 0.5
    right = 1.75
    No_of_points = 15

    #H4 Ring
    radius = 0.5*np.sqrt(2)
    angles = np.linspace(np.pi/12, np.pi/12*5, 30)

    # H6 Linear
    left = 0.5
    right = 3.2
    No_of_points = 30

    # LiH
    left = 0.55
    right = 4.0
    No_of_points = 30

    # H2O
    left = 0.65
    right = 1.425
    No_of_points = 15

    # BeH2
    left = 0.75
    right = 3.75
    No_of_points = 30
    '''

    # H4 Linear
    left = 0.5
    right = 1.75
    No_of_points = 15


    R = np.linspace(left, right, No_of_points)              #The Bond length for the molecule with number of points = "No_of_points"


    #Running the VQE for various bond lengths
    
#     R = []
#     for r_idx in range (len(angles)):                     #Uncomment this if simulating H4 Ring as its parametrization is different from other molecules.
#       theta = angles[r_idx]                               #Uncomment this if simulating H4 Ring
#       r = radius*np.cos(theta)*2                          #Uncomment this if simulating H4 Ring. r is just a measure of molecular srtucture.
#       R.append(r)                                         #Uncomment this if simulating H4 Ring
    for r_idx in range (len(R)):                            
      if len(Bond_Lengths) == 0:                            
          r = R[r_idx]                                      
      else:                                                 
          r_idx = len(Bond_Lengths)                         
          r = R[r_idx]                                      


            
      print ('\n \n _______________________Bond Length = %f    and    iteration number = %i out of %i_______________________' %(r, r_idx+1, len(R)))
      print ('Building molecule... \n')
      
      #Building the molecule
      molecule = Molecule(
          # coordinates are given in Angstrom
          geometry=[
#               BeH2 and LiH:
#               ["Be", [0.0, 0.0, 0.0]],
#               ["H", [0.0, 0.0, -r]],
#               ["H", [0.0, 0.0, r]],
#               ["Li", [0.0, 0.0, 0.0]],

#               H2O:
#               ["O", [0.0, 0.0, 0.0]],
#               ["H", [np.cos(0.911498202)*r,  np.sin(0.911498202)*r, 0.0]],
#               ["H", [np.cos(0.911498202)*r, -np.sin(0.911498202)*r, 0.0]],
            
#               H4 Ring: 
#               ["H", [0.0, radius*np.cos(theta), radius*np.sin(theta)]],
#               ["H", [0.0, radius*np.cos(theta), -radius*np.sin(theta)]],
#               ["H", [0.0, -radius*np.cos(theta), radius*np.sin(theta)]],
#               ["H", [0.0, -radius*np.cos(theta), -radius*np.sin(theta)]],
            
#               H4 linear and H6 linear:
              ["H", [0.0, 0.0, 0.0]],
              ["H", [0.0, 0.0, 0.0+r]],
              ["H", [0.0, 0.0, 0.0+2*r]],
              ["H", [0.0, 0.0, 0.0+3*r]],
#               ["H", [0.0, 0.0, 0.0+4*r]],
#               ["H", [0.0, 0.0, 0.0+5*r]]
          ],
          multiplicity=1,  # = 2*spin + 1
          charge=0,
      )
      driver = ElectronicStructureMoleculeDriver(
          molecule, basis="sto3g", driver_type=ElectronicStructureDriverType.PYSCF
      )

      problem = ElectronicStructureProblem(driver)
      second_q_op = problem.second_q_ops()

      qubit_converter = QubitConverter(mapper = JordanWignerMapper(), two_qubit_reduction = True)
      Hamiltonian = qubit_converter.convert(second_q_op[0], num_particles=problem.num_particles)

      nso = int(problem.num_spin_orbitals/2)        #Number of SPATIAL orbitals
      nelec = problem.num_particles                 #Number of alpha and beta electrons in a tuple format

      print ('Building molecule completed! \n')












      print ('Calculating true ground state energy... \n')

      #Calculating the exact energy
      def exact_diagonalizer(problem, qubit_converter):
          solver = NumPyMinimumEigensolverFactory()
          calc = GroundStateEigensolver(qubit_converter, solver)
          result = calc.solve(problem)
          return result

      result_exact = exact_diagonalizer(problem, qubit_converter)
      exact_energy = np.real(result_exact.eigenenergies[0])
      # print('Exact solution: \n', result_exact)

      molecule_True_Energies.append(result_exact.groundenergy + result_exact.nuclear_repulsion_energy)

      print ('Calculating true ground state energy completed! The ground state energy = %f \n'%(result_exact.groundenergy + result_exact.nuclear_repulsion_energy))

      H4_Linear_True_Energies = copy.copy(molecule_True_Energies)
      if case_idx == 0:
          with open('Final data/Pre ML Data/H4_Linear/H4_Linear_True_Energies.pkl', 'wb') as outfile:
              pickle.dump(H4_Linear_True_Energies, outfile, pickle.HIGHEST_PROTOCOL)



      #Defining the Hartree-Fock state
      HF = HartreeFock(num_spin_orbitals=nso*2, num_particles=nelec, qubit_converter=QubitConverter(mapper=JordanWignerMapper(), two_qubit_reduction=True))


      #Performing the UCC-VQE based on the case chosen above

      iter_count = 0
      temp_UCC_op = UCC(num_spin_orbitals=nso*2, num_particles=nelec, excitations=[1, 2], qubit_converter=QubitConverter(mapper=JordanWignerMapper(), two_qubit_reduction=True), initial_state = HF)
      all_excitations = temp_UCC_op.excitation_list
      t = all_excitations

      # Performing Spin adapted VQE
      if include_spin_adaptation == 'True':
        print ('__________________spin Adaptation has been applied__________________ \n')

        perform_spin_adaptation(all_excitations)

        def custom_excitation_list(num_spin_orbitals, num_particles):    #Needed to pass it to the UCC operator generator in the next step
          return spin_nonadapted_exct
        UCC_operator = UCC(num_spin_orbitals=nso*2, num_particles=nelec, excitations=custom_excitation_list, qubit_converter=QubitConverter(mapper=JordanWignerMapper(), two_qubit_reduction=True), initial_state = HF)
        t = UCC_operator.parameters

        # Spin adapted | small amplitude filtered VQE
        if include_spin_filtration == 'True':
          algorithm = VQE(UCC_operator, optimizer=optimizer, quantum_instance=backend)
          energy_eval_func = algorithm.get_energy_evaluation(Hamiltonian, False)
          x_0 = np.zeros(len(spin_adapted_exct))
          adapted_ordered_params = np.zeros((1, len(spin_adapted_exct)))    #Initiating the array that stores the cluster amplitudes at each step of minimization

          adapted_ordered_params = spin_adapted_VQE(2)     #Kappa = 2

          removable_idx_1 = []
          j = np.flip(np.argsort(np.abs(adapted_ordered_params[-1, :])))    #Sorting the cluster amplitudes based on their absolute values
          
          #Generating the list of amplitudes that can be removed according to the scheme of small amplitude filtration defined in the paper.
          for i in j:
              if np.abs(adapted_ordered_params[1,i] - adapted_ordered_params[0,i]) < 1e-4 and np.abs(adapted_ordered_params[1,i]) < 1e-5:
                  removable_idx_1.append(i)
          nonadapted_removable_idx = []
          for i in removable_idx_1:
                  nonadapted_removable_idx = nonadapted_removable_idx + adapted_to_nonadapted_idx(i)

          for i in range (len(adapted_t_ij_ab_idx)):
              try:
                  a = removable_idx_1.index(adapted_t_ij_ab_idx[i]) 
                  if adapted_t_iJ_aB_idx[i] in removable_idx_1:
                      nonadapted_removable_idx = nonadapted_removable_idx + [nonadapted_t_iJ_Ab_idx[i], nonadapted_t_Ij_aB_idx[i]]
              except ValueError:
                  pass

          #Storing the removable indices
          molecule_spin_adapted_Removable_Idx.append(removable_idx_1)
          molecule_nonspin_adapted_Removable_Idx.append(nonadapted_removable_idx)

          relevant_excitations = [spin_nonadapted_exct[i] for i in range (len(spin_nonadapted_exct)) if i not in nonadapted_removable_idx]

          perform_spin_adaptation(relevant_excitations)

          def custom_excitation_list(num_spin_orbitals, num_particles):
            return spin_nonadapted_exct
          UCC_operator = UCC(num_spin_orbitals=nso*2, num_particles=nelec, excitations=custom_excitation_list, qubit_converter=QubitConverter(mapper=JordanWignerMapper(), two_qubit_reduction=True), initial_state = HF)
          t = UCC_operator.parameters
          algorithm = VQE(UCC_operator, optimizer=optimizer, quantum_instance=backend)
          energy_eval_func = algorithm.get_energy_evaluation(Hamiltonian, False)

          adapted_ordered_params = np.zeros((1,len(spin_adapted_exct)))

          print ('__________________small amplitude filtration has been applied__________________ \n')

          x_0 = np.zeros((len(spin_adapted_exct)))
          t0 = time.perf_counter()
          adapted_ordered_params = spin_adapted_VQE(maxiter)
          t1 = time.perf_counter()

          molecule_SA_1_SAF_1_Params.append(adapted_ordered_params)
          molecule_SA_1_SAF_1_Energies.append(adapted_energy_eval_func(adapted_ordered_params[-1, :]) + result_exact.nuclear_repulsion_energy)
          molecule_SA_1_SAF_1_Time.append(t1-t0)

            
          #Storing the results into .pkl files
          H4_Linear_SA_1_SAF_1_Params = copy.copy(molecule_SA_1_SAF_1_Params)
          H4_Linear_SA_1_SAF_1_Energies = copy.copy(molecule_SA_1_SAF_1_Energies)
          H4_Linear_SA_1_SAF_1_Time = copy.copy(molecule_SA_1_SAF_1_Time)
          H4_Linear_spin_adapted_Removable_Idx = copy.copy(molecule_spin_adapted_Removable_Idx)
          H4_Linear_nonspin_adapted_Removable_Idx = copy.copy(molecule_nonspin_adapted_Removable_Idx)  
          
          with open('Final data/Pre ML Data/H4_Linear/H4_Linear_SA_1_SAF_1_Params.pkl', 'wb') as outfile:
                pickle.dump(H4_Linear_SA_1_SAF_1_Params, outfile, pickle.HIGHEST_PROTOCOL)

          with open('Final data/Pre ML Data/H4_Linear/H4_Linear_SA_1_SAF_1_Energies.pkl', 'wb') as outfile:
                pickle.dump(H4_Linear_SA_1_SAF_1_Energies, outfile, pickle.HIGHEST_PROTOCOL)

          with open('Final data/Pre ML Data/H4_Linear/H4_Linear_SA_1_SAF_1_Time.pkl', 'wb') as outfile:
                pickle.dump(H4_Linear_SA_1_SAF_1_Time, outfile, pickle.HIGHEST_PROTOCOL)

          with open('Final data/Pre ML Data/H4_Linear/H4_Linear_spin_adapted_Removable_Idx.pkl', 'wb') as outfile:
                pickle.dump(H4_Linear_spin_adapted_Removable_Idx, outfile, pickle.HIGHEST_PROTOCOL)

          with open('Final data/Pre ML Data/H4_Linear/H4_Linear_nonspin_adapted_Removable_Idx.pkl', 'wb') as outfile:
                pickle.dump(H4_Linear_nonspin_adapted_Removable_Idx, outfile, pickle.HIGHEST_PROTOCOL)
            
            
            
            
            
            
            
            
            
            
            
            
            
        # Performing Spin adapted | non small amplitude filtered VQE
        else:
          print ('\n __________________small amplitude filtration has NOT been applied__________________ \n')
          algorithm = VQE(UCC_operator, optimizer=optimizer, quantum_instance=backend)
          energy_eval_func = algorithm.get_energy_evaluation(Hamiltonian, False)

          adapted_ordered_params = np.zeros((1,len(spin_adapted_exct)))
          x_0 = np.zeros(len(spin_adapted_exct))
          t0 = time.perf_counter()
          adapted_ordered_params = spin_adapted_VQE(maxiter)
          t1 = time.perf_counter()

          molecule_SA_1_SAF_0_Params.append(adapted_ordered_params)
          molecule_SA_1_SAF_0_Energies.append(adapted_energy_eval_func(adapted_ordered_params[-1, :]) + result_exact.nuclear_repulsion_energy)
          molecule_SA_1_SAF_0_Time.append(t1-t0)
        
        
        
          H4_Linear_SA_1_SAF_0_Params = copy.copy(molecule_SA_1_SAF_0_Params)
          H4_Linear_SA_1_SAF_0_Energies = copy.copy(molecule_SA_1_SAF_0_Energies)
          H4_Linear_SA_1_SAF_0_Time = copy.copy(molecule_SA_1_SAF_0_Time)

          with open('Final data/Pre ML Data/H4_Linear/H4_Linear_SA_1_SAF_0_Params.pkl', 'wb') as outfile:
              pickle.dump(H4_Linear_SA_1_SAF_0_Params, outfile, pickle.HIGHEST_PROTOCOL)

          with open('Final data/Pre ML Data/H4_Linear/H4_Linear_SA_1_SAF_0_Energies.pkl', 'wb') as outfile:
              pickle.dump(H4_Linear_SA_1_SAF_0_Energies, outfile, pickle.HIGHEST_PROTOCOL)

          with open('Final data/Pre ML Data/H4_Linear/H4_Linear_SA_1_SAF_0_Time.pkl', 'wb') as outfile:
              pickle.dump(H4_Linear_SA_1_SAF_0_Time, outfile, pickle.HIGHEST_PROTOCOL)
        
        
        
        
        
        
        
        
        
      # Performing nonspin adapted VQE
      else:
        print ('__________________spin adaptation has NOT been applied__________________ \n')

        #Just to have a consistent order of excitations
        perform_spin_adaptation(all_excitations)

        def custom_excitation_list(num_spin_orbitals, num_particles):
          return spin_nonadapted_exct
        UCC_operator = UCC(num_spin_orbitals=nso*2, num_particles=nelec, excitations=custom_excitation_list, qubit_converter=QubitConverter(mapper=JordanWignerMapper(), two_qubit_reduction=True), initial_state = HF)
        t = UCC_operator.parameters

        # Nonspin adapted | small amplitude filtered VQE 
        #Note, this is not a part of the paper and hence this specific case will be skipped while running the code (refer to the list "All_cases" defined above).
        if include_spin_filtration == 'True':

          algorithm = VQE(UCC_operator, optimizer=optimizer, quantum_instance=backend)
          energy_eval_func = algorithm.get_energy_evaluation(Hamiltonian, False)
          
          ordered_params = np.zeros((1,len(t)))
          x_0 = np.zeros(len(t))
          ordered_params = nonspin_adapted_VQE(2)

          removable_idx = []
          j = np.arange(len(ordered_params[-1, :]))
          for i in j:
            if np.abs(ordered_params[1,i] - ordered_params[0,i]) < 1e-4 and np.abs(ordered_params[1,i]) < 1e-5:
              removable_idx.append(i)

          #Storing the removable indices
          molecule_UCCSD_Removable_Idx.append(removable_idx)

          def custom_excitation_list(num_spin_orbitals, num_particles):
            removed_excitations = [all_excitations[i] for i in range (len(all_excitations)) if i not in removable_idx]
            return removed_excitations

          UCC_operator = UCC(num_spin_orbitals=nso*2, num_particles=nelec, excitations=custom_excitation_list, qubit_converter=QubitConverter(mapper=JordanWignerMapper(), two_qubit_reduction=True), initial_state = HF)
          t = UCC_operator.parameters
          x_0 = np.zeros(len(t))
          algorithm = VQE(UCC_operator, optimizer=optimizer, quantum_instance=backend)
          energy_eval_func = algorithm.get_energy_evaluation(Hamiltonian, False)

          print ('\n __________________small amplitude filtration has been applied__________________ \n')
          ordered_params = np.zeros((1,len(t)))
          ordered_params = nonspin_adapted_VQE(maxiter)

        # Performing Nonspin adapted | non small amplitude filtered VQE
        else:
          print ('__________________small amplitude filtration has NOT been applied__________________ \n')

          algorithm = VQE(UCC_operator, optimizer=optimizer, quantum_instance=backend)
          energy_eval_func = algorithm.get_energy_evaluation(Hamiltonian, False)
          ordered_params = np.zeros((1,len(t)))
          x_0 = np.zeros(len(t))

          t0 = time.perf_counter()
          ordered_params = nonspin_adapted_VQE(maxiter)
          t1 = time.perf_counter()

          molecule_SA_0_SAF_0_Params.append(ordered_params)
          molecule_SA_0_SAF_0_Energies.append(energy_eval_func(ordered_params[-1, :]) + result_exact.nuclear_repulsion_energy)
          molecule_SA_0_SAF_0_Time.append(t1-t0)

        
          #Saving the results into .pkl files
          H4_Linear_SA_0_SAF_0_Params = copy.copy(molecule_SA_0_SAF_0_Params)
          H4_Linear_SA_0_SAF_0_Energies = copy.copy(molecule_SA_0_SAF_0_Energies)
          H4_Linear_SA_0_SAF_0_Time = copy.copy(molecule_SA_0_SAF_0_Time)
        
          
          with open('Final data/Pre ML Data/H4_Linear/H4_Linear_SA_0_SAF_0_Params.pkl', 'wb') as outfile:
              pickle.dump(H4_Linear_SA_0_SAF_0_Params, outfile, pickle.HIGHEST_PROTOCOL)

          with open('Final data/Pre ML Data/H4_Linear/H4_Linear_SA_0_SAF_0_Energies.pkl', 'wb') as outfile:
              pickle.dump(H4_Linear_SA_0_SAF_0_Energies, outfile, pickle.HIGHEST_PROTOCOL)

          with open('Final data/Pre ML Data/H4_Linear/H4_Linear_SA_0_SAF_0_Time.pkl', 'wb') as outfile:
              pickle.dump(H4_Linear_SA_0_SAF_0_Time, outfile, pickle.HIGHEST_PROTOCOL)
        
        
        
        
        
      Bond_Lengths.append(r)
      with open('Final data/Pre ML Data/H4_Linear/Bond_Lengths.pkl', 'wb') as outfile:
            pickle.dump(Bond_Lengths, outfile, pickle.HIGHEST_PROTOCOL)
      if len(Bond_Lengths) == len(R):
        break
    Cases_Completed.append(case_idx)
    with open('Final data/Pre ML Data/H4_Linear/Cases_Completed.pkl', 'wb') as outfile:
        pickle.dump(Cases_Completed, outfile, pickle.HIGHEST_PROTOCOL)
        
    Bond_Lengths = []
    with open('Final data/Pre ML Data/H4_Linear/Bond_Lengths.pkl', 'wb') as outfile:
        pickle.dump(Bond_Lengths, outfile, pickle.HIGHEST_PROTOCOL)
    
    print ('_______________________________Case  %i completed_______________________________'%(case_idx+1))
    if len(Cases_Completed) == len(All_cases):
        break
        
        
print ('\n \n \n The code has been executed successfully!')
# Out:
# _______________________________Starting case: 1_______________________________
#
#
#  _______________________Bond Length = 0.500000    and    iteration number = 1 out of 15_______________________
# Building molecule...
#
# Building molecule completed!
#
# Calculating true ground state energy...
#
# Calculating true ground state energy completed! The ground state energy = -1.653117
#
# __________________spin Adaptation has been applied__________________
#
# Energy at the initial parameter values:  -1.6286097030298352
# Iteration 1:    Energy = -1.642657
# Iteration 2:    Energy = -1.647053
# Final energy after minimization:  -1.6470528914044875
# Time ellapsed:  5.709801041999981
#
# __________________small amplitude filtration has been applied__________________
#
# Energy at the initial parameter values:  -1.6286097030298725
# Iteration 3:    Energy = -1.642657
# Iteration 4:    Energy = -1.647053
# Iteration 5:    Energy = -1.649630
# Iteration 6:    Energy = -1.652139
# Iteration 7:    Energy = -1.652839
# Iteration 8:    Energy = -1.653086
# Iteration 9:    Energy = -1.653109
# Iteration 10:    Energy = -1.653111
# Iteration 11:    Energy = -1.653111
# Final energy after minimization:  -1.6531107446108733
# Time ellapsed:  4.416196851999985
#
#
#
#  _______________________Bond Length = 0.589286    and    iteration number = 2 out of 15_______________________
# Building molecule...
#
# Building molecule completed!
#
# Calculating true ground state energy...
#
# Calculating true ground state energy completed! The ground state energy = -1.936783
#
# __________________spin Adaptation has been applied__________________
#
# Energy at the initial parameter values:  -1.906858382713505
# Iteration 1:    Energy = -1.923297
# Iteration 2:    Energy = -1.930308
# Final energy after minimization:  -1.9303078596003473
# Time ellapsed:  4.716643224999871
#
# __________________small amplitude filtration has been applied__________________
#
# Energy at the initial parameter values:  -1.9068583827135388
# Iteration 3:    Energy = -1.923297
# Iteration 4:    Energy = -1.930308
# Iteration 5:    Energy = -1.933100
# Iteration 6:    Energy = -1.936292
# Iteration 7:    Energy = -1.936686
# Iteration 8:    Energy = -1.936772
# Iteration 9:    Energy = -1.936777
# Iteration 10:    Energy = -1.936777
# Iteration 11:    Energy = -1.936777
# Final energy after minimization:  -1.9367769088286693
# Time ellapsed:  4.607159397000032
#
#
#
#  _______________________Bond Length = 0.678571    and    iteration number = 3 out of 15_______________________
# Building molecule...
#
# Building molecule completed!
#
# Calculating true ground state energy...
#
# Calculating true ground state energy completed! The ground state energy = -2.084595
#
# __________________spin Adaptation has been applied__________________
#
# Energy at the initial parameter values:  -2.0484254267668467
# Iteration 1:    Energy = -2.067350
# Iteration 2:    Energy = -2.077290
# Final energy after minimization:  -2.0772896567837167
# Time ellapsed:  4.735685074000003
#
# __________________small amplitude filtration has been applied__________________
#
# Energy at the initial parameter values:  -2.0484254267668787
# Iteration 3:    Energy = -2.067350
# Iteration 4:    Energy = -2.077290
# Iteration 5:    Energy = -2.080837
# Iteration 6:    Energy = -2.084307
# Iteration 7:    Energy = -2.084494
# Iteration 8:    Energy = -2.084581
# Iteration 9:    Energy = -2.084587
# Iteration 10:    Energy = -2.084588
# Iteration 11:    Energy = -2.084588
# Final energy after minimization:  -2.084588442263975
# Time ellapsed:  4.472306714000069
#
#
#
#  _______________________Bond Length = 0.767857    and    iteration number = 4 out of 15_______________________
# Building molecule...
#
# Building molecule completed!
#
# Calculating true ground state energy...
#
# Calculating true ground state energy completed! The ground state energy = -2.154695
#
# __________________spin Adaptation has been applied__________________
#
# Energy at the initial parameter values:  -2.111360503406346
# Iteration 1:    Energy = -2.132992
# Iteration 2:    Energy = -2.145881
# Final energy after minimization:  -2.1458806739650407
# Time ellapsed:  5.2294664759999705
#
# __________________small amplitude filtration has been applied__________________
#
# Energy at the initial parameter values:  -2.111360503406376
# Iteration 3:    Energy = -2.132992
# Iteration 4:    Energy = -2.145881
# Iteration 5:    Energy = -2.150926
# Iteration 6:    Energy = -2.154260
# Iteration 7:    Energy = -2.154640
# Iteration 8:    Energy = -2.154680
# Iteration 9:    Energy = -2.154684
# Iteration 10:    Energy = -2.154684
# Final energy after minimization:  -2.1546837735920605
# Time ellapsed:  4.14370642699987
#
#
#
#  _______________________Bond Length = 0.857143    and    iteration number = 5 out of 15_______________________
# Building molecule...
#
# Building molecule completed!
#
# Calculating true ground state energy...
#
# Calculating true ground state energy completed! The ground state energy = -2.179077
#
# __________________spin Adaptation has been applied__________________
#
# Energy at the initial parameter values:  -2.127464409581915
# Iteration 1:    Energy = -2.152213
# Iteration 2:    Energy = -2.168021
# Final energy after minimization:  -2.168021312092491
# Time ellapsed:  4.652491435000002
#
# __________________small amplitude filtration has been applied__________________
#
# Energy at the initial parameter values:  -2.127464409581944
# Iteration 3:    Energy = -2.152213
# Iteration 4:    Energy = -2.168021
# Iteration 5:    Energy = -2.175287
# Iteration 6:    Energy = -2.178251
# Iteration 7:    Energy = -2.178985
# Iteration 8:    Energy = -2.179050
# Iteration 9:    Energy = -2.179053
# Iteration 10:    Energy = -2.179053
# Iteration 11:    Energy = -2.179053
# Final energy after minimization:  -2.179053088800674
# Time ellapsed:  4.236573621000161
#
#
#
#  _______________________Bond Length = 0.946429    and    iteration number = 6 out of 15_______________________
# Building molecule...
#
# Building molecule completed!
#
# Calculating true ground state energy...
#
# Calculating true ground state energy completed! The ground state energy = -2.176283
#
# __________________spin Adaptation has been applied__________________
#
# Energy at the initial parameter values:  -2.1150167298978397
# Iteration 1:    Energy = -2.143460
# Iteration 2:    Energy = -2.162247
# Final energy after minimization:  -2.16224735824483
# Time ellapsed:  4.5834987400000955
#
# __________________small amplitude filtration has been applied__________________
#
# Energy at the initial parameter values:  -2.1150167298978664
# Iteration 3:    Energy = -2.143460
# Iteration 4:    Energy = -2.162247
# Iteration 5:    Energy = -2.172389
# Iteration 6:    Energy = -2.175082
# Iteration 7:    Energy = -2.176102
# Iteration 8:    Energy = -2.176225
# Iteration 9:    Energy = -2.176227
# Iteration 10:    Energy = -2.176231
# Iteration 11:    Energy = -2.176231
# Final energy after minimization:  -2.176230902091378
# Time ellapsed:  4.504756750999832
#
#
#
#  _______________________Bond Length = 1.035714    and    iteration number = 7 out of 15_______________________
# Building molecule...
#
# Building molecule completed!
#
# Calculating true ground state energy...
#
# Calculating true ground state energy completed! The ground state energy = -2.157438
#
# __________________spin Adaptation has been applied__________________
#
# Energy at the initial parameter values:  -2.0848468658006483
# Iteration 1:    Energy = -2.117690
# Iteration 2:    Energy = -2.139641
# Final energy after minimization:  -2.1396412600505115
# Time ellapsed:  4.668899361000058
#
# __________________small amplitude filtration has been applied__________________
#
# Energy at the initial parameter values:  -2.084846865800675
# Iteration 3:    Energy = -2.117690
# Iteration 4:    Energy = -2.139641
# Iteration 5:    Energy = -2.153313
# Iteration 6:    Energy = -2.155834
# Iteration 7:    Energy = -2.157125
# Iteration 8:    Energy = -2.157327
# Iteration 9:    Energy = -2.157331
# Iteration 10:    Energy = -2.157333
# Iteration 11:    Energy = -2.157333
# Final energy after minimization:  -2.157332661220956
# Time ellapsed:  4.544179910999901
#
#
#
#  _______________________Bond Length = 1.125000    and    iteration number = 8 out of 15_______________________
# Building molecule...
#
# Building molecule completed!
#
# Calculating true ground state energy...
# Calculating true ground state energy completed! The ground state energy = -2.129554
#
# __________________spin Adaptation has been applied__________________
#
# Energy at the initial parameter values:  -2.0436739164449405
# Iteration 1:    Energy = -2.081717
# Iteration 2:    Energy = -2.107123
# Final energy after minimization:  -2.107123306617245
# Time ellapsed:  4.6665736610000295
#
# __________________small amplitude filtration has been applied__________________
#
# Energy at the initial parameter values:  -2.0436739164449635
# Iteration 3:    Energy = -2.081717
# Iteration 4:    Energy = -2.107123
# Iteration 5:    Energy = -2.125051
# Iteration 6:    Energy = -2.127460
# Iteration 7:    Energy = -2.129045
# Iteration 8:    Energy = -2.129339
# Iteration 9:    Energy = -2.129353
# Iteration 10:    Energy = -2.129355
# Iteration 11:    Energy = -2.129355
# Iteration 12:    Energy = -2.129355
# Final energy after minimization:  -2.1293552264737237
# Time ellapsed:  5.1131752710000455
#
#
#
#  _______________________Bond Length = 1.214286    and    iteration number = 9 out of 15_______________________
# Building molecule...
#
# Building molecule completed!
#
# Calculating true ground state energy...
#
# Calculating true ground state energy completed! The ground state energy = -2.097301
#
# __________________spin Adaptation has been applied__________________
#
# Energy at the initial parameter values:  -1.9959239879146493
# Iteration 1:    Energy = -2.040022
# Iteration 2:    Energy = -2.069254
# Final energy after minimization:  -2.0692538229304924
# Time ellapsed:  4.6966631479999705
#
# __________________small amplitude filtration has been applied__________________
#
# Energy at the initial parameter values:  -1.9959239879146733
# Iteration 3:    Energy = -2.040022
# Iteration 4:    Energy = -2.069254
# Iteration 5:    Energy = -2.092270
# Iteration 6:    Energy = -2.094586
# Iteration 7:    Energy = -2.096512
# Iteration 8:    Energy = -2.096903
# Iteration 9:    Energy = -2.096912
# Iteration 10:    Energy = -2.096953
# Iteration 11:    Energy = -2.096954
# Iteration 12:    Energy = -2.096954
# Final energy after minimization:  -2.0969537312848203
# Time ellapsed:  4.8490714689999095
#
#
#
#  _______________________Bond Length = 1.303571    and    iteration number = 10 out of 15_______________________
# Building molecule...
#
# Building molecule completed!
#
# Calculating true ground state energy...
#
# Calculating true ground state energy completed! The ground state energy = -2.063901
#
# __________________spin Adaptation has been applied__________________
#
# Energy at the initial parameter values:  -1.9446525044092804
# Iteration 1:    Energy = -1.995681
# Iteration 2:    Energy = -2.029150
# Final energy after minimization:  -2.0291503142975564
# Time ellapsed:  4.6392993030001435
#
# __________________small amplitude filtration has been applied__________________
#
# Energy at the initial parameter values:  -1.944652504409303
# Iteration 3:    Energy = -1.995681
# Iteration 4:    Energy = -2.029150
# Iteration 5:    Energy = -2.058193
# Iteration 6:    Energy = -2.060401
# Iteration 7:    Energy = -2.062745
# Iteration 8:    Energy = -2.063187
# Iteration 9:    Energy = -2.063293
# Iteration 10:    Energy = -2.063330
# Iteration 11:    Energy = -2.063330
# Iteration 12:    Energy = -2.063330
# Final energy after minimization:  -2.0633304941976647
# Time ellapsed:  4.862033655000005
#
#
#
#  _______________________Bond Length = 1.392857    and    iteration number = 11 out of 15_______________________
# Building molecule...
#
# Building molecule completed!
#
# Calculating true ground state energy...
#
# Calculating true ground state energy completed! The ground state energy = -2.031564
#
# __________________spin Adaptation has been applied__________________
#
# Energy at the initial parameter values:  -1.8920117450357135
# Iteration 1:    Energy = -1.950829
# Iteration 2:    Energy = -1.988956
# Final energy after minimization:  -1.9889556240808612
# Time ellapsed:  4.655200052000055
#
# __________________small amplitude filtration has been applied__________________
#
# Energy at the initial parameter values:  -1.8920117450357348
# Iteration 3:    Energy = -1.950829
# Iteration 4:    Energy = -1.988956
# Iteration 5:    Energy = -2.025029
# Iteration 6:    Energy = -2.027109
# Iteration 7:    Energy = -2.029862
# Iteration 8:    Energy = -2.030435
# Iteration 9:    Energy = -2.030625
# Iteration 10:    Energy = -2.030678
# Iteration 11:    Energy = -2.030678
# Iteration 12:    Energy = -2.030678
# Final energy after minimization:  -2.0306784513426424
# Time ellapsed:  4.838933817999987
#
#
#
#  _______________________Bond Length = 1.482143    and    iteration number = 12 out of 15_______________________
# Building molecule...
#
# Building molecule completed!
#
# Calculating true ground state energy...
#
# Calculating true ground state energy completed! The ground state energy = -2.001732
#
# __________________spin Adaptation has been applied__________________
#
# Energy at the initial parameter values:  -1.8395185867289978
# Iteration 1:    Energy = -1.906923
# Iteration 2:    Energy = -1.950107
# Final energy after minimization:  -1.9501067473211386
# Time ellapsed:  4.645202382000207
#
# __________________small amplitude filtration has been applied__________________
#
# Energy at the initial parameter values:  -1.8395185867290182
# Iteration 3:    Energy = -1.906923
# Iteration 4:    Energy = -1.950107
# Iteration 5:    Energy = -1.994198
# Iteration 6:    Energy = -1.996191
# Iteration 7:    Energy = -1.998472
# Iteration 8:    Energy = -2.000061
# Iteration 9:    Energy = -2.000305
# Iteration 10:    Energy = -2.000430
# Iteration 11:    Energy = -2.000433
# Iteration 12:    Energy = -2.000433
# Final energy after minimization:  -2.0004332087063657
# Time ellapsed:  5.122459320000189
#
#
#
#  _______________________Bond Length = 1.571429    and    iteration number = 13 out of 15_______________________
# Building molecule...
#
# Building molecule completed!
#
# Calculating true ground state energy...
#
# Calculating true ground state energy completed! The ground state energy = -1.975253
#
# __________________spin Adaptation has been applied__________________
#
# Energy at the initial parameter values:  -1.7882329347230985
# Iteration 1:    Energy = -1.864921
# Iteration 2:    Energy = -1.913519
# Final energy after minimization:  -1.9135193725031632
# Time ellapsed:  4.551369171000033
#
# __________________small amplitude filtration has been applied__________________
#
# Energy at the initial parameter values:  -1.788232934723118
# Iteration 3:    Energy = -1.864921
# Iteration 4:    Energy = -1.913519
# Iteration 5:    Energy = -1.966473
# Iteration 6:    Energy = -1.968579
# Iteration 7:    Energy = -1.969863
# Iteration 8:    Energy = -1.971701
# Iteration 9:    Energy = -1.972301
# Iteration 10:    Energy = -1.973391
# Iteration 11:    Energy = -1.973440
# Iteration 12:    Energy = -1.973445
# Iteration 13:    Energy = -1.973445
# Iteration 14:    Energy = -1.973445
# Final energy after minimization:  -1.9734447380973965
# Time ellapsed:  5.69155866899996
#
#
#
#  _______________________Bond Length = 1.660714    and    iteration number = 14 out of 15_______________________
# Building molecule...
#
# Building molecule completed!
#
# Calculating true ground state energy...
#
# Calculating true ground state energy completed! The ground state energy = -1.952504
#
# __________________spin Adaptation has been applied__________________
#
# Energy at the initial parameter values:  -1.738884564079724
# Iteration 1:    Energy = -1.825409
# Iteration 2:    Energy = -1.879721
# Final energy after minimization:  -1.879720805914162
# Time ellapsed:  4.6423317050000605
#
# __________________small amplitude filtration has been applied__________________
#
# Energy at the initial parameter values:  -1.7388845640797421
# Iteration 3:    Energy = -1.825409
# Iteration 4:    Energy = -1.879721
# Iteration 5:    Energy = -1.942095
# Iteration 6:    Energy = -1.944758
# Iteration 7:    Energy = -1.945473
# Iteration 8:    Energy = -1.946681
# Iteration 9:    Energy = -1.948960
# Iteration 10:    Energy = -1.949561
# Iteration 11:    Energy = -1.950093
# Iteration 12:    Energy = -1.950110
# Iteration 13:    Energy = -1.950110
# Iteration 14:    Energy = -1.950110
# Final energy after minimization:  -1.950110461306204
# Time ellapsed:  5.648328412999945
#
#
#
#  _______________________Bond Length = 1.750000    and    iteration number = 15 out of 15_______________________
# Building molecule...
# Building molecule completed!
#
# Calculating true ground state energy...
#
# Calculating true ground state energy completed! The ground state energy = -1.933507
#
# __________________spin Adaptation has been applied__________________
#
# Energy at the initial parameter values:  -1.6919624112048934
# Iteration 1:    Energy = -1.788692
# Iteration 2:    Energy = -1.848955
# Final energy after minimization:  -1.8489549183001972
# Time ellapsed:  4.624415836000026
#
# __________________small amplitude filtration has been applied__________________
#
# Energy at the initial parameter values:  -1.691962411204912
# Iteration 3:    Energy = -1.788692
# Iteration 4:    Energy = -1.848955
# Iteration 5:    Energy = -1.920878
# Iteration 6:    Energy = -1.924792
# Iteration 7:    Energy = -1.925406
# Iteration 8:    Energy = -1.925940
# Iteration 9:    Energy = -1.927122
# Iteration 10:    Energy = -1.928816
# Iteration 11:    Energy = -1.929674
# Iteration 12:    Energy = -1.930255
# Iteration 13:    Energy = -1.930466
# Iteration 14:    Energy = -1.930487
# Iteration 15:    Energy = -1.930487
# Iteration 16:    Energy = -1.930487
# Final energy after minimization:  -1.9304873898476518
# Time ellapsed:  6.342645620999974
#
# _______________________________Case  1 completed_______________________________
# _______________________________Starting case: 2_______________________________
#
#
#  _______________________Bond Length = 0.500000    and    iteration number = 1 out of 15_______________________
# Building molecule...
#
# Building molecule completed!
#
# Calculating true ground state energy...
#
# Calculating true ground state energy completed! The ground state energy = -1.653117
#
# __________________spin Adaptation has been applied__________________
#
#
#  __________________small amplitude filtration has NOT been applied__________________
#
# Energy at the initial parameter values:  -1.628609703029837
# Iteration 1:    Energy = -1.642657
# Iteration 2:    Energy = -1.647053
# Iteration 3:    Energy = -1.649630
# Iteration 4:    Energy = -1.652139
# Iteration 5:    Energy = -1.652839
# Iteration 6:    Energy = -1.653086
# Iteration 7:    Energy = -1.653109
# Iteration 8:    Energy = -1.653111
# Iteration 9:    Energy = -1.653111
# Final energy after minimization:  -1.6531107445841249
# Time ellapsed:  13.443823188999886
#
#
#
#  _______________________Bond Length = 0.589286    and    iteration number = 2 out of 15_______________________
# Building molecule...
#
# Building molecule completed!
#
# Calculating true ground state energy...
#
# Calculating true ground state energy completed! The ground state energy = -1.936783
#
# __________________spin Adaptation has been applied__________________
#
#
#  __________________small amplitude filtration has NOT been applied__________________
#
# Energy at the initial parameter values:  -1.9068583827135024
# Iteration 1:    Energy = -1.923297
# Iteration 2:    Energy = -1.930308
# Iteration 3:    Energy = -1.933100
# Iteration 4:    Energy = -1.936292
# Iteration 5:    Energy = -1.936686
# Iteration 6:    Energy = -1.936772
# Iteration 7:    Energy = -1.936777
# Iteration 8:    Energy = -1.936777
# Iteration 9:    Energy = -1.936777
# Final energy after minimization:  -1.9367769088275129
# Time ellapsed:  12.865292002999922
#
#
#
#  _______________________Bond Length = 0.678571    and    iteration number = 3 out of 15_______________________
# Building molecule...
#
# Building molecule completed!
#
# Calculating true ground state energy...
#
# Calculating true ground state energy completed! The ground state energy = -2.084595
#
# __________________spin Adaptation has been applied__________________
#
#
#  __________________small amplitude filtration has NOT been applied__________________
#
# Energy at the initial parameter values:  -2.0484254267668485
# Iteration 1:    Energy = -2.067350
# Iteration 2:    Energy = -2.077290
# Iteration 3:    Energy = -2.080837
# Iteration 4:    Energy = -2.084307
# Iteration 5:    Energy = -2.084494
# Iteration 6:    Energy = -2.084581
# Iteration 7:    Energy = -2.084587
# Iteration 8:    Energy = -2.084588
# Iteration 9:    Energy = -2.084588
# Final energy after minimization:  -2.0845884420736063
# Time ellapsed:  13.530453642999873
#
#
#
#  _______________________Bond Length = 0.767857    and    iteration number = 4 out of 15_______________________
# Building molecule...
#
# Building molecule completed!
#
# Calculating true ground state energy...
#
# Calculating true ground state energy completed! The ground state energy = -2.154695
#
# __________________spin Adaptation has been applied__________________
#
#
#  __________________small amplitude filtration has NOT been applied__________________
#
# Energy at the initial parameter values:  -2.111360503406346
# Iteration 1:    Energy = -2.132992
# Iteration 2:    Energy = -2.145881
# Iteration 3:    Energy = -2.150926
# Iteration 4:    Energy = -2.154260
# Iteration 5:    Energy = -2.154640
# Iteration 6:    Energy = -2.154680
# Iteration 7:    Energy = -2.154684
# Iteration 8:    Energy = -2.154684
# Final energy after minimization:  -2.154683773587808
# Time ellapsed:  11.615489092999951
#
#
#
#  _______________________Bond Length = 0.857143    and    iteration number = 5 out of 15_______________________
# Building molecule...
#
# Building molecule completed!
#
# Calculating true ground state energy...
#
# Calculating true ground state energy completed! The ground state energy = -2.179077
#
# __________________spin Adaptation has been applied__________________
#
#
#  __________________small amplitude filtration has NOT been applied__________________
#
# Energy at the initial parameter values:  -2.127464409581915
# Iteration 1:    Energy = -2.152213
# Iteration 2:    Energy = -2.168021
# Iteration 3:    Energy = -2.175287
# Iteration 4:    Energy = -2.178251
# Iteration 5:    Energy = -2.178985
# Iteration 6:    Energy = -2.179050
# Iteration 7:    Energy = -2.179053
# Iteration 8:    Energy = -2.179053
# Iteration 9:    Energy = -2.179053
# Final energy after minimization:  -2.179053088793073
# Time ellapsed:  12.771103757999981
#
#
#
#  _______________________Bond Length = 0.946429    and    iteration number = 6 out of 15_______________________
# Building molecule...
#
# Building molecule completed!
#
# Calculating true ground state energy...
#
# Calculating true ground state energy completed! The ground state energy = -2.176283
#
# __________________spin Adaptation has been applied__________________
#
#
#  __________________small amplitude filtration has NOT been applied__________________
#
# Energy at the initial parameter values:  -2.1150167298978406
# Iteration 1:    Energy = -2.143460
# Iteration 2:    Energy = -2.162247
# Iteration 3:    Energy = -2.172389
# Iteration 4:    Energy = -2.175082
# Iteration 5:    Energy = -2.176102
# Iteration 6:    Energy = -2.176225
# Iteration 7:    Energy = -2.176227
# Iteration 8:    Energy = -2.176231
# Iteration 9:    Energy = -2.176231
# Final energy after minimization:  -2.176230902081265
# Time ellapsed:  12.669045417000007
#
#
#
#  _______________________Bond Length = 1.035714    and    iteration number = 7 out of 15_______________________
# Building molecule...
#
# Building molecule completed!
#
# Calculating true ground state energy...
#
# Calculating true ground state energy completed! The ground state energy = -2.157438
#
# __________________spin Adaptation has been applied__________________
#
#
#  __________________small amplitude filtration has NOT been applied__________________
#
# Energy at the initial parameter values:  -2.0848468658006474
# Iteration 1:    Energy = -2.117690
# Iteration 2:    Energy = -2.139641
# Iteration 3:    Energy = -2.153313
# Iteration 4:    Energy = -2.155834
# Iteration 5:    Energy = -2.157125
# Iteration 6:    Energy = -2.157327
# Iteration 7:    Energy = -2.157331
# Iteration 8:    Energy = -2.157333
# Iteration 9:    Energy = -2.157333
# Final energy after minimization:  -2.1573326612968446
# Time ellapsed:  13.343471088000115
#
#
#
#  _______________________Bond Length = 1.125000    and    iteration number = 8 out of 15_______________________
# Building molecule...
#
# Building molecule completed!
#
# Calculating true ground state energy...
#
# Calculating true ground state energy completed! The ground state energy = -2.129554
#
# __________________spin Adaptation has been applied__________________
#
#
#  __________________small amplitude filtration has NOT been applied__________________
# Energy at the initial parameter values:  -2.043673916444937
# Iteration 1:    Energy = -2.081717
# Iteration 2:    Energy = -2.107123
# Iteration 3:    Energy = -2.125051
# Iteration 4:    Energy = -2.127460
# Iteration 5:    Energy = -2.129045
# Iteration 6:    Energy = -2.129339
# Iteration 7:    Energy = -2.129353
# Iteration 8:    Energy = -2.129355
# Iteration 9:    Energy = -2.129355
# Iteration 10:    Energy = -2.129355
# Final energy after minimization:  -2.1293552264684728
# Time ellapsed:  15.054382343000043
#
#
#
#  _______________________Bond Length = 1.214286    and    iteration number = 9 out of 15_______________________
# Building molecule...
#
# Building molecule completed!
#
# Calculating true ground state energy...
#
# Calculating true ground state energy completed! The ground state energy = -2.097301
#
# __________________spin Adaptation has been applied__________________
#
#
#  __________________small amplitude filtration has NOT been applied__________________
#
# Energy at the initial parameter values:  -1.9959239879146506
# Iteration 1:    Energy = -2.040022
# Iteration 2:    Energy = -2.069254
# Iteration 3:    Energy = -2.092270
# Iteration 4:    Energy = -2.094586
# Iteration 5:    Energy = -2.096512
# Iteration 6:    Energy = -2.096903
# Iteration 7:    Energy = -2.096912
# Iteration 8:    Energy = -2.096953
# Iteration 9:    Energy = -2.096954
# Iteration 10:    Energy = -2.096954
# Final energy after minimization:  -2.0969537313047795
# Time ellapsed:  14.22623290699994
#
#
#
#  _______________________Bond Length = 1.303571    and    iteration number = 10 out of 15_______________________
# Building molecule...
#
# Building molecule completed!
#
# Calculating true ground state energy...
#
# Calculating true ground state energy completed! The ground state energy = -2.063901
#
# __________________spin Adaptation has been applied__________________
#
#
#  __________________small amplitude filtration has NOT been applied__________________
#
# Energy at the initial parameter values:  -1.94465250440928
# Iteration 1:    Energy = -1.995681
# Iteration 2:    Energy = -2.029150
# Iteration 3:    Energy = -2.058193
# Iteration 4:    Energy = -2.060401
# Iteration 5:    Energy = -2.062745
# Iteration 6:    Energy = -2.063187
# Iteration 7:    Energy = -2.063293
# Iteration 8:    Energy = -2.063330
# Iteration 9:    Energy = -2.063330
# Iteration 10:    Energy = -2.063330
# Final energy after minimization:  -2.063330494162904
# Time ellapsed:  13.733083053999962
#
#
#
#  _______________________Bond Length = 1.392857    and    iteration number = 11 out of 15_______________________
# Building molecule...
#
# Building molecule completed!
#
# Calculating true ground state energy...
#
# Calculating true ground state energy completed! The ground state energy = -2.031564
#
# __________________spin Adaptation has been applied__________________
#
#
#  __________________small amplitude filtration has NOT been applied__________________
#
# Energy at the initial parameter values:  -1.8920117450357121
# Iteration 1:    Energy = -1.950829
# Iteration 2:    Energy = -1.988956
# Iteration 3:    Energy = -2.025029
# Iteration 4:    Energy = -2.027109
# Iteration 5:    Energy = -2.029862
# Iteration 6:    Energy = -2.030435
# Iteration 7:    Energy = -2.030625
# Iteration 8:    Energy = -2.030678
# Iteration 9:    Energy = -2.030678
# Iteration 10:    Energy = -2.030678
# Iteration 11:    Energy = -2.030678
# Final energy after minimization:  -2.0306784515463345
# Time ellapsed:  14.941009427999916
#
#
#
#  _______________________Bond Length = 1.482143    and    iteration number = 12 out of 15_______________________
# Building molecule...
#
# Building molecule completed!
#
# Calculating true ground state energy...
#
# Calculating true ground state energy completed! The ground state energy = -2.001732
#
# __________________spin Adaptation has been applied__________________
#
#
#  __________________small amplitude filtration has NOT been applied__________________
#
# Energy at the initial parameter values:  -1.8395185867289983
# Iteration 1:    Energy = -1.906923
# Iteration 2:    Energy = -1.950107
# Iteration 3:    Energy = -1.994198
# Iteration 4:    Energy = -1.996191
# Iteration 5:    Energy = -1.998472
# Iteration 6:    Energy = -2.000061
# Iteration 7:    Energy = -2.000305
# Iteration 8:    Energy = -2.000430
# Iteration 9:    Energy = -2.000433
# Iteration 10:    Energy = -2.000433
# Final energy after minimization:  -2.000433197459937
# Time ellapsed:  15.97862998100004
#
#
#
#  _______________________Bond Length = 1.571429    and    iteration number = 13 out of 15_______________________
# Building molecule...
#
# Building molecule completed!
#
# Calculating true ground state energy...
#
# Calculating true ground state energy completed! The ground state energy = -1.975253
#
# __________________spin Adaptation has been applied__________________
#
#
#  __________________small amplitude filtration has NOT been applied__________________
#
# Energy at the initial parameter values:  -1.7882329347231025
# Iteration 1:    Energy = -1.864921
# Iteration 2:    Energy = -1.913519
# Iteration 3:    Energy = -1.966473
# Iteration 4:    Energy = -1.968579
# Iteration 5:    Energy = -1.969863
# Iteration 6:    Energy = -1.971701
# Iteration 7:    Energy = -1.972301
# Iteration 8:    Energy = -1.973391
# Iteration 9:    Energy = -1.973440
# Iteration 10:    Energy = -1.973445
# Iteration 11:    Energy = -1.973445
# Iteration 12:    Energy = -1.973445
# Final energy after minimization:  -1.9734447365831114
# Time ellapsed:  16.063181832000055
#
#
#
#  _______________________Bond Length = 1.660714    and    iteration number = 14 out of 15_______________________
# Building molecule...
#
# Building molecule completed!
#
# Calculating true ground state energy...
#
# Calculating true ground state energy completed! The ground state energy = -1.952504
#
# __________________spin Adaptation has been applied__________________
#
#
#  __________________small amplitude filtration has NOT been applied__________________
#
# Energy at the initial parameter values:  -1.738884564079724
# Iteration 1:    Energy = -1.825409
# Iteration 2:    Energy = -1.879721
# Iteration 3:    Energy = -1.942095
# Iteration 4:    Energy = -1.944758
# Iteration 5:    Energy = -1.945473
# Iteration 6:    Energy = -1.946681
# Iteration 7:    Energy = -1.948960
# Iteration 8:    Energy = -1.949561
# Iteration 9:    Energy = -1.950093
# Iteration 10:    Energy = -1.950110
# Iteration 11:    Energy = -1.950110
# Iteration 12:    Energy = -1.950110
# Iteration 13:    Energy = -1.950110
# Final energy after minimization:  -1.9501104601226844
# Time ellapsed:  17.714097466000112
#
#
#
#  _______________________Bond Length = 1.750000    and    iteration number = 15 out of 15_______________________
# Building molecule...
#
# Building molecule completed!
#
# Calculating true ground state energy...
#
# Calculating true ground state energy completed! The ground state energy = -1.933507
#
# __________________spin Adaptation has been applied__________________
#
#
#  __________________small amplitude filtration has NOT been applied__________________
#
# Energy at the initial parameter values:  -1.6919624112048974
# Iteration 1:    Energy = -1.788692
# Iteration 2:    Energy = -1.848955
# Iteration 3:    Energy = -1.920878
# Iteration 4:    Energy = -1.924792
# Iteration 5:    Energy = -1.925406
# Iteration 6:    Energy = -1.925940
# Iteration 7:    Energy = -1.927121
# Iteration 8:    Energy = -1.928816
# Iteration 9:    Energy = -1.929673
# Iteration 10:    Energy = -1.930246
# Iteration 11:    Energy = -1.930445
# Iteration 12:    Energy = -1.930477
# Iteration 13:    Energy = -1.930487
# Iteration 14:    Energy = -1.930487
# Iteration 15:    Energy = -1.930487
# Final energy after minimization:  -1.930487393710267
# Time ellapsed:  19.84835615099996
#
# _______________________________Case  2 completed_______________________________
# _______________________________Starting case: 3_______________________________
#
#
#  _______________________Bond Length = 0.500000    and    iteration number = 1 out of 15_______________________
# Building molecule...
#
# Building molecule completed!
#
# Calculating true ground state energy...
#
# Calculating true ground state energy completed! The ground state energy = -1.653117
#
# __________________spin adaptation has NOT been applied__________________
#
# __________________small amplitude filtration has NOT been applied__________________
# Energy at the initial parameter values:  -1.6286097030298352
# Iteration 1:    Energy = -1.647956
# Iteration 2:    Energy = -1.652096
# Iteration 3:    Energy = -1.652992
# Iteration 4:    Energy = -1.653091
# Iteration 5:    Energy = -1.653108
# Iteration 6:    Energy = -1.653110
# Iteration 7:    Energy = -1.653111
# Iteration 8:    Energy = -1.653111
# Iteration 9:    Energy = -1.653111
# Final energy after minimization:  -1.6531107465287036
# Time ellapsed:  22.327519203000065
#
#
#
#  _______________________Bond Length = 0.589286    and    iteration number = 2 out of 15_______________________
# Building molecule...
#
# Building molecule completed!
#
# Calculating true ground state energy...
#
# Calculating true ground state energy completed! The ground state energy = -1.936783
#
# __________________spin adaptation has NOT been applied__________________
#
# __________________small amplitude filtration has NOT been applied__________________
#
# Energy at the initial parameter values:  -1.9068583827135024
# Iteration 1:    Energy = -1.931087
# Iteration 2:    Energy = -1.935731
# Iteration 3:    Energy = -1.936652
# Iteration 4:    Energy = -1.936760
# Iteration 5:    Energy = -1.936774
# Iteration 6:    Energy = -1.936776
# Iteration 7:    Energy = -1.936777
# Iteration 8:    Energy = -1.936777
# Final energy after minimization:  -1.936776906713117
# Time ellapsed:  20.325531988999956
#
#
#
#  _______________________Bond Length = 0.678571    and    iteration number = 3 out of 15_______________________
# Building molecule...
#
# Building molecule completed!
#
# Calculating true ground state energy...
#
# Calculating true ground state energy completed! The ground state energy = -2.084595
#
# __________________spin adaptation has NOT been applied__________________
#
# __________________small amplitude filtration has NOT been applied__________________
#
# Energy at the initial parameter values:  -2.0484254267668485
# Iteration 1:    Energy = -2.078255
# Iteration 2:    Energy = -2.083462
# Iteration 3:    Energy = -2.084445
# Iteration 4:    Energy = -2.084571
# Iteration 5:    Energy = -2.084585
# Iteration 6:    Energy = -2.084588
# Iteration 7:    Energy = -2.084588
# Iteration 8:    Energy = -2.084588
# Final energy after minimization:  -2.0845884338114207
# Time ellapsed:  20.308358854000062
#
#
#
#  _______________________Bond Length = 0.767857    and    iteration number = 4 out of 15_______________________
# Building molecule...
#
# Building molecule completed!
#
# Calculating true ground state energy...
#
# Calculating true ground state energy completed! The ground state energy = -2.154695
#
# __________________spin adaptation has NOT been applied__________________
#
# __________________small amplitude filtration has NOT been applied__________________
#
# Energy at the initial parameter values:  -2.111360503406346
# Iteration 1:    Energy = -2.147613
# Iteration 2:    Energy = -2.153439
# Iteration 3:    Energy = -2.154509
# Iteration 4:    Energy = -2.154663
# Iteration 5:    Energy = -2.154680
# Iteration 6:    Energy = -2.154684
# Iteration 7:    Energy = -2.154684
# Iteration 8:    Energy = -2.154684
# Final energy after minimization:  -2.154683777557224
# Time ellapsed:  20.36352898500013
#
#
#
#  _______________________Bond Length = 0.857143    and    iteration number = 5 out of 15_______________________
# Building molecule...
#
# Building molecule completed!
#
# Calculating true ground state energy...
#
# Calculating true ground state energy completed! The ground state energy = -2.179077
#
# __________________spin adaptation has NOT been applied__________________
#
# __________________small amplitude filtration has NOT been applied__________________
#
# Energy at the initial parameter values:  -2.127464409581912
# Iteration 1:    Energy = -2.171170
# Iteration 2:    Energy = -2.177656
# Iteration 3:    Energy = -2.178831
# Iteration 4:    Energy = -2.179022
# Iteration 5:    Energy = -2.179049
# Iteration 6:    Energy = -2.179052
# Iteration 7:    Energy = -2.179053
# Iteration 8:    Energy = -2.179053
# Final energy after minimization:  -2.1790530974092297
# Time ellapsed:  20.311609324000074
#
#
#
#  _______________________Bond Length = 0.946429    and    iteration number = 6 out of 15_______________________
# Building molecule...
#
# Building molecule completed!
#
# Calculating true ground state energy...
#
# Calculating true ground state energy completed! The ground state energy = -2.176283
#
# __________________spin adaptation has NOT been applied__________________
#
# __________________small amplitude filtration has NOT been applied__________________
#
# Energy at the initial parameter values:  -2.1150167298978415
# Iteration 1:    Energy = -2.167465
# Iteration 2:    Energy = -2.174644
# Iteration 3:    Energy = -2.175937
# Iteration 4:    Energy = -2.176176
# Iteration 5:    Energy = -2.176227
# Iteration 6:    Energy = -2.176229
# Iteration 7:    Energy = -2.176231
# Iteration 8:    Energy = -2.176231
# Final energy after minimization:  -2.1762309349461546
# Time ellapsed:  20.72681427700013
#
#
#
#  _______________________Bond Length = 1.035714    and    iteration number = 7 out of 15_______________________
# Building molecule...
#
# Building molecule completed!
#
# Calculating true ground state energy...
#
# Calculating true ground state energy completed! The ground state energy = -2.157438
#
# __________________spin adaptation has NOT been applied__________________
#
# __________________small amplitude filtration has NOT been applied__________________
#
# Energy at the initial parameter values:  -2.0848468658006474
# Iteration 1:    Energy = -2.147617
# Iteration 2:    Energy = -2.155508
# Iteration 3:    Energy = -2.156935
# Iteration 4:    Energy = -2.157231
# Iteration 5:    Energy = -2.157328
# Iteration 6:    Energy = -2.157332
# Iteration 7:    Energy = -2.157333
# Iteration 8:    Energy = -2.157333
# Final energy after minimization:  -2.1573327616759186
# Time ellapsed:  22.268712799000014
#
#
#
#  _______________________Bond Length = 1.125000    and    iteration number = 8 out of 15_______________________
# Building molecule...
#
# Building molecule completed!
#
# Calculating true ground state energy...
#
# Calculating true ground state energy completed! The ground state energy = -2.129554
#
# __________________spin adaptation has NOT been applied__________________
#
# __________________small amplitude filtration has NOT been applied__________________
#
# Energy at the initial parameter values:  -2.0436739164449413
# Iteration 1:    Energy = -2.118630
# Iteration 2:    Energy = -2.127232
# Iteration 3:    Energy = -2.128807
# Iteration 4:    Energy = -2.129168
# Iteration 5:    Energy = -2.129345
# Iteration 6:    Energy = -2.129355
# Iteration 7:    Energy = -2.129355
# Iteration 8:    Energy = -2.129355
# Final energy after minimization:  -2.129355481730334
# Time ellapsed:  22.335447119000037
#
#
#
#  _______________________Bond Length = 1.214286    and    iteration number = 9 out of 15_______________________
# Building molecule...
#
# Building molecule completed!
#
# Calculating true ground state energy...
#
# Calculating true ground state energy completed! The ground state energy = -2.097301
#
# __________________spin adaptation has NOT been applied__________________
#
# __________________small amplitude filtration has NOT been applied__________________
#
# Energy at the initial parameter values:  -1.995923987914652
# Iteration 1:    Energy = -2.085183
# Iteration 2:    Energy = -2.094472
# Iteration 3:    Energy = -2.096191
# Iteration 4:    Energy = -2.096620
# Iteration 5:    Energy = -2.096929
# Iteration 6:    Energy = -2.096951
# Iteration 7:    Energy = -2.096954
# Iteration 8:    Energy = -2.096954
# Final energy after minimization:  -2.0969543152377295
# Time ellapsed:  22.346481650999976
#
#
#
#  _______________________Bond Length = 1.303571    and    iteration number = 10 out of 15_______________________
# Building molecule...
#
# Building molecule completed!
#
# Calculating true ground state energy...
#
# Calculating true ground state energy completed! The ground state energy = -2.063901
#
# __________________spin adaptation has NOT been applied__________________
#
# __________________small amplitude filtration has NOT been applied__________________
#
# Energy at the initial parameter values:  -1.9446525044092795
# Iteration 1:    Energy = -2.050516
# Iteration 2:    Energy = -2.060455
# Iteration 3:    Energy = -2.062274
# Iteration 4:    Energy = -2.062769
# Iteration 5:    Energy = -2.063276
# Iteration 6:    Energy = -2.063322
# Iteration 7:    Energy = -2.063332
# Iteration 8:    Energy = -2.063332
# Iteration 9:    Energy = -2.063332
# Iteration 10:    Energy = -2.063332
# Final energy after minimization:  -2.063331740525741
# Time ellapsed:  26.296498358999997
#
#
#
#  _______________________Bond Length = 1.392857    and    iteration number = 11 out of 15_______________________
# Building molecule...
#
# Building molecule completed!
#
# Calculating true ground state energy...
#
# Calculating true ground state energy completed! The ground state energy = -2.031564
#
# __________________spin adaptation has NOT been applied__________________
#
# __________________small amplitude filtration has NOT been applied__________________
#
# Energy at the initial parameter values:  -1.8920117450357117
# Iteration 1:    Energy = -2.016868
# Iteration 2:    Energy = -2.027429
# Iteration 3:    Energy = -2.029238
# Iteration 4:    Energy = -2.029796
# Iteration 5:    Energy = -2.030612
# Iteration 6:    Energy = -2.030667
# Iteration 7:    Energy = -2.030681
# Iteration 8:    Energy = -2.030681
# Iteration 9:    Energy = -2.030681
# Final energy after minimization:  -2.030680768413788
# Time ellapsed:  24.71744794899996
#
#
#
#  _______________________Bond Length = 1.482143    and    iteration number = 12 out of 15_______________________
# Building molecule...
#
# Building molecule completed!
#
# Calculating true ground state energy...
#
# Calculating true ground state energy completed! The ground state energy = -2.001732
#
# __________________spin adaptation has NOT been applied__________________
#
# __________________small amplitude filtration has NOT been applied__________________
#
# Energy at the initial parameter values:  -1.8395185867289965
# Iteration 1:    Energy = -1.985704
# Iteration 2:    Energy = -1.996901
# Iteration 3:    Energy = -1.998531
# Iteration 4:    Energy = -1.999152
# Iteration 5:    Energy = -2.000363
# Iteration 6:    Energy = -2.000389
# Iteration 7:    Energy = -2.000436
# Iteration 8:    Energy = -2.000437
# Iteration 9:    Energy = -2.000437
# Iteration 10:    Energy = -2.000437
# Final energy after minimization:  -2.000437090730276
# Time ellapsed:  24.485949411999854
#
#
#
#  _______________________Bond Length = 1.571429    and    iteration number = 13 out of 15_______________________
# Building molecule...
#
# Building molecule completed!
#
# Calculating true ground state energy...
#
# Calculating true ground state energy completed! The ground state energy = -1.975253
#
# __________________spin adaptation has NOT been applied__________________
#
# __________________small amplitude filtration has NOT been applied__________________
#
# Energy at the initial parameter values:  -1.788232934723102
# Iteration 1:    Energy = -1.840692
# Iteration 2:    Energy = -1.956703
# Iteration 3:    Energy = -1.965875
# Iteration 4:    Energy = -1.970832
# Iteration 5:    Energy = -1.971504
# Iteration 6:    Energy = -1.973372
# Iteration 7:    Energy = -1.973421
# Iteration 8:    Energy = -1.973450
# Iteration 9:    Energy = -1.973450
# Iteration 10:    Energy = -1.973451
# Iteration 11:    Energy = -1.973451
# Iteration 12:    Energy = -1.973451
# Final energy after minimization:  -1.9734506230120281
# Time ellapsed:  30.57186594199993
#
#
#
#  _______________________Bond Length = 1.660714    and    iteration number = 14 out of 15_______________________
# Building molecule...
#
# Building molecule completed!
#
# Calculating true ground state energy...
#
# Calculating true ground state energy completed! The ground state energy = -1.952504
#
# __________________spin adaptation has NOT been applied__________________
#
# __________________small amplitude filtration has NOT been applied__________________
#
# Energy at the initial parameter values:  -1.738884564079723
# Iteration 1:    Energy = -1.846829
# Iteration 2:    Energy = -1.933251
# Iteration 3:    Energy = -1.945939
# Iteration 4:    Energy = -1.946967
# Iteration 5:    Energy = -1.947819
# Iteration 6:    Energy = -1.949656
# Iteration 7:    Energy = -1.949980
# Iteration 8:    Energy = -1.950115
# Iteration 9:    Energy = -1.950118
# Iteration 10:    Energy = -1.950119
# Iteration 11:    Energy = -1.950119
# Iteration 12:    Energy = -1.950119
# Final energy after minimization:  -1.9501186454090926
# Time ellapsed:  26.575188877000073
#
#
#
#  _______________________Bond Length = 1.750000    and    iteration number = 15 out of 15_______________________
# Building molecule...
#
# Building molecule completed!
#
# Calculating true ground state energy...
#
# Calculating true ground state energy completed! The ground state energy = -1.933507
#
# __________________spin adaptation has NOT been applied__________________
#
# __________________small amplitude filtration has NOT been applied__________________
#
# Energy at the initial parameter values:  -1.6919624112048934
# Iteration 1:    Energy = -1.849111
# Iteration 2:    Energy = -1.913849
# Iteration 3:    Energy = -1.926398
# Iteration 4:    Energy = -1.926929
# Iteration 5:    Energy = -1.928055
# Iteration 6:    Energy = -1.929817
# Iteration 7:    Energy = -1.930323
# Iteration 8:    Energy = -1.930486
# Iteration 9:    Energy = -1.930497
# Iteration 10:    Energy = -1.930498
# Iteration 11:    Energy = -1.930498
# Iteration 12:    Energy = -1.930498
# Iteration 13:    Energy = -1.930498
# Final energy after minimization:  -1.930498019249005
# Time ellapsed:  31.0376554569998
#
# _______________________________Case  3 completed_______________________________
#
#
#
#  The code has been executed successfully!

# %% [markdown]
# ### Loading the data:
# All the data produced in the algorithm are stored in .pkl files. In order to load them back to perform further analysis, run the following code block.

# %%
with open('Final data/Pre ML Data/H4_Linear/H4_Linear_True_Energies.pkl', 'rb') as infile:
    H4_Linear_True_Energies = pickle.load(infile)





with open('Final data/Pre ML Data/H4_Linear/H4_Linear_SA_0_SAF_0_Params.pkl', 'rb') as infile:
    H4_Linear_SA_0_SAF_0_Params = pickle.load(infile)

with open('Final data/Pre ML Data/H4_Linear/H4_Linear_SA_0_SAF_0_Energies.pkl', 'rb') as infile:
    H4_Linear_SA_0_SAF_0_Energies = pickle.load(infile)

with open('Final data/Pre ML Data/H4_Linear/H4_Linear_SA_0_SAF_0_Time.pkl', 'rb') as infile:
    H4_Linear_SA_0_SAF_0_Time = pickle.load(infile)





with open('Final data/Pre ML Data/H4_Linear/H4_Linear_SA_1_SAF_0_Params.pkl', 'rb') as infile:
    H4_Linear_SA_1_SAF_0_Params = pickle.load(infile)

with open('Final data/Pre ML Data/H4_Linear/H4_Linear_SA_1_SAF_0_Energies.pkl', 'rb') as infile:
    H4_Linear_SA_1_SAF_0_Energies = pickle.load(infile)

with open('Final data/Pre ML Data/H4_Linear/H4_Linear_SA_1_SAF_0_Time.pkl', 'rb') as infile:
    H4_Linear_SA_1_SAF_0_Time = pickle.load(infile)





with open('Final data/Pre ML Data/H4_Linear/H4_Linear_SA_1_SAF_1_Params.pkl', 'rb') as infile:
    H4_Linear_SA_1_SAF_1_Params = pickle.load(infile)

with open('Final data/Pre ML Data/H4_Linear/H4_Linear_SA_1_SAF_1_Energies.pkl', 'rb') as infile:
    H4_Linear_SA_1_SAF_1_Energies = pickle.load(infile)

with open('Final data/Pre ML Data/H4_Linear/H4_Linear_SA_1_SAF_1_Time.pkl', 'rb') as infile:
    H4_Linear_SA_1_SAF_1_Time = pickle.load(infile)

with open('Final data/Pre ML Data/H4_Linear/H4_Linear_spin_adapted_Removable_Idx.pkl', 'rb') as infile:
    H4_Linear_spin_adapted_Removable_Idx = pickle.load(infile)

with open('Final data/Pre ML Data/H4_Linear/H4_Linear_nonspin_adapted_Removable_Idx.pkl', 'rb') as infile:
    H4_Linear_nonspin_adapted_Removable_Idx = pickle.load(infile)

# %% [markdown]
# ## Results:

# %% [markdown]
# ### Average of Filtered Amplitudes

# %%
# H4_Linear
H4_Linear_max_removable_param = []
for i in range (len(H4_Linear_SA_0_SAF_0_Params)):
    ordered_params = H4_Linear_SA_0_SAF_0_Params[i]
    temp_idx = []
    for j in range (len(ordered_params[-1,:])):
        if np.abs(ordered_params[1,j] - ordered_params[0,j]) < 1e-4 and np.abs(ordered_params[1,j]) < 1e-5:
          temp_idx.append(j)
    b = ordered_params[-1,temp_idx]
    H4_Linear_max_removable_param.append(np.mean(b))
    
plt.plot(H4_Linear_max_removable_param, '.-', label = 'H$_4$ Linear')
plt.xlabel('Bond length index')
plt.ylabel('Avg value of filtered amplitudes')
plt.show()

# %% [markdown]
# ### Potential Energy Surface

# %%
#H4_Linear
left = 0.5
right = 1.75
No_of_points = 15
R = np.linspace(left, right, No_of_points)
R=R

plt.figure(figsize=(14, 3)) 
plt.subplot(1,3,1)
plt.plot(R, H4_Linear_True_Energies, label='True energy')
plt.plot(R, H4_Linear_SA_0_SAF_0_Energies, '.', label='Conventional UCCSD-VQE')

plt.legend()
plt.title('H$_4$ Linear PES')
plt.xlabel('Bond Length in A$^\circ$')
plt.ylabel('Energy in Hartree')

plt.subplot(1,3,2)
plt.ticklabel_format(style='sci', axis='y', scilimits=(-3,10))
plt.plot(R, np.array(H4_Linear_SA_0_SAF_0_Energies)-np.array(H4_Linear_SA_1_SAF_0_Energies), color='c')
plt.title('H$_4$ Linear SA-UCCSD Error')
plt.xlabel('Bond Length in A$^\circ$')
plt.ylabel('Error', labelpad=1)

plt.subplot(1,3,3)
plt.plot(R, np.array(H4_Linear_SA_1_SAF_0_Energies)-np.array(H4_Linear_SA_1_SAF_1_Energies), color='y')
plt.title('H$_4$ Linear SA-SA_SAF Error ')
plt.xlabel('Bond Length in A$^\circ$')
plt.show()

# %% [markdown]
# ### Number of Amplitudes

# %%
H4_Linear_no_SA_0_SAF_0_Params = len(H4_Linear_SA_0_SAF_0_Params[10][-1,:])
H4_Linear_no_SA_1_SAF_0_Params = len(H4_Linear_SA_1_SAF_0_Params[10][-1,:])
H4_Linear_no_SA_1_SAF_1_Params = len(H4_Linear_SA_1_SAF_1_Params[10][-1,:])
H4_Linear_11 = H4_Linear_no_SA_1_SAF_1_Params
H4_Linear_10 = H4_Linear_no_SA_1_SAF_0_Params
H4_Linear_00 = H4_Linear_no_SA_0_SAF_0_Params



All_11 = [H4_Linear_11]
All_10 = [H4_Linear_10]
All_00 = [H4_Linear_00]



Molecules = ['H$_4$ Linear']
df = pd.DataFrame({'Spin adapted and small amplitude filtered': All_11, 'Spin adapted': All_10,
                   'All parameters': All_00}, index=Molecules)

ax = df.plot.bar(stacked=False, ylim=(0,max(All_00)+10), rot=0)
ax.set_xlabel("Molecules")
ax.set_ylabel("Number of parameters")
plt.show()

# %% [markdown]
# ### Time Taken for Convergence

# %%
#H4_Linear
left = 0.5
right = 1.75
No_of_points = 15
R = np.linspace(left, right, No_of_points)
R=R

plt.title('H$_4$ Linear')

plt.plot(R, H4_Linear_SA_0_SAF_0_Time, label='Conventional UCCSD-VQE')
plt.plot(R, H4_Linear_SA_1_SAF_0_Time, label='Spin adapted UCCSD-VQE')
plt.plot(R, H4_Linear_SA_1_SAF_1_Time, label='Spin adapted small amplitude filtered UCCSD-VQE')

plt.ylim(0,50)
plt.xlabel('Bond Length in A$^\circ$')
plt.ylabel('Time in seconds')
plt.legend()
plt.show()
